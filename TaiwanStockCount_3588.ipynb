# %% [markdown]
# <a href="https://colab.research.google.com/github/cwcheng0/practicepython/blob/master/TaiwanStockCount_3588.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To Read Taiwan Tourism Bureau data and make it into HTML
# Use Python to read directly from local drive
# Taiwan Stock Data1 https://bsr.twse.com.tw/bshtm/
# Filename: 3588_20201123.csv
# Taiwan Stock Data2 https://www.tpex.org.tw/web/stock/aftertrading/broker_trading/brokerBS.php
# Load basic libraries
import pandas as pd
import numpy as np

# %%
# yodate files
# upload a file
from google.colab import files
names = files.upload()
# Out:
#      <input type="file" id="files-5a1ecb99-7f60-4b56-974f-c48c4d1d45a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a1ecb99-7f60-4b56-974f-c48c4d1d45a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3588.csv to 3588.csv

# %%
# Check first 5 rows in a file
# Read a File from local drive code
# For OTC, please use a different method to read Big5
df = pd.read_csv('3588.csv',encoding='big5hkscs',skiprows=2)
df.head()

# Notice datatypes changed in some columns.
# Check first few rows.
df.head()
# Out:
#    序號        券商     價格  買進股數  賣出股數  ...  序號.1      券商.1   價格.1  買進股數.1  賣出股數.1
# 0   1  1020合　　庫  43.90  1000     0  ...   2.0  1020合　　庫  44.10  1000.0      0
# 1   3  1020合　　庫  44.15  6000     0  ...   4.0  1020合　　庫  44.60  1000.0      0
# 2   5  1020合　　庫  47.40  1000     0  ...   6.0  1020合　　庫  48.00     0.0   1000
# 3   7  1021合庫台中  44.05  1000     0  ...   8.0  1021合庫台中  44.50     0.0   2000
# 4   9  1021合庫台中  45.80  1000     0  ...  10.0  1021合庫台中  46.85  1000.0   1000
#
# [5 rows x 11 columns]

# %%
# Drop some columns.
df = df.drop(df.columns[[5]], axis=1) 
df.head()
# Out:
#    序號        券商     價格  買進股數  賣出股數  序號.1      券商.1   價格.1  買進股數.1 賣出股數.1
# 0   1  1020合　　庫  43.90  1000     0   2.0  1020合　　庫  44.10  1000.0     0
# 1   3  1020合　　庫  44.15  6000     0   4.0  1020合　　庫  44.60  1000.0     0
# 2   5  1020合　　庫  47.40  1000     0   6.0  1020合　　庫  48.00     0.0  1000
# 3   7  1021合庫台中  44.05  1000     0   8.0  1021合庫台中  44.50     0.0  2000
# 4   9  1021合庫台中  45.80  1000     0  10.0  1021合庫台中  46.85  1000.0  1000

# %%
# Split fields into 2 files.
# Copy files
df1 = df
df2 = df
df1 = df1.drop(df.columns[[5,6,7,8,9]], axis=1) 
df1.head()
# Out:
#    序號        券商     價格  買進股數  賣出股數
# 0   1  1020合　　庫  43.90  1000     0
# 1   3  1020合　　庫  44.15  6000     0
# 2   5  1020合　　庫  47.40  1000     0
# 3   7  1021合庫台中  44.05  1000     0
# 4   9  1021合庫台中  45.80  1000     0

# %%
# Do it again
df2 = df2.drop(df2.columns[[0,1,2,3,4]], axis=1) 
df2.head()
# Out:
#    序號.1      券商.1   價格.1  買進股數.1 賣出股數.1
# 0   2.0  1020合　　庫  44.10  1000.0     0
# 1   4.0  1020合　　庫  44.60  1000.0     0
# 2   6.0  1020合　　庫  48.00     0.0  1000
# 3   8.0  1021合庫台中  44.50     0.0  2000
# 4  10.0  1021合庫台中  46.85  1000.0  1000

# %%
# check datatypes
df2.dtypes
# Out:
# 序號.1      float64
# 券商.1       object
# 價格.1      float64
# 買進股數.1    float64
# 賣出股數.1     object
# dtype: object

# %%
# Change column names
df2.columns = ['序號', '券商', '價格', '買進股數', '賣出股數']
df2.head()
# Out:
#      序號        券商     價格    買進股數   賣出股數
# 0   2.0  1020合　　庫  44.10  1000.0     0
# 1   4.0  1020合　　庫  44.60  1000.0     0
# 2   6.0  1020合　　庫  48.00     0.0  1000
# 3   8.0  1021合庫台中  44.50     0.0  2000
# 4  10.0  1021合庫台中  46.85  1000.0  1000

# %%
# Check last row data
df2.tail()
# Out:
#           序號        券商    價格    買進股數   賣出股數
# 2368  4738.0  9A9Y永豐板盛  44.6  1000.0     0
# 2369  4740.0  9A9Y永豐板盛  47.4  1000.0     0
# 2370  4742.0  9A9Z永豐復興  47.0     0.0  2000
# 2371  4744.0  9A9Z永豐復興  48.0     0.0  2000
# 2372     NaN       NaN   NaN     NaN

# %%
# Check if there is a Nan?
df2.dropna(subset = ["買進股數"], inplace=True)
df2.tail()
# Out:
#           序號        券商    價格    買進股數   賣出股數
# 2367  4736.0  9A9X永豐竹科  47.0  2000.0     0
# 2368  4738.0  9A9Y永豐板盛  44.6  1000.0     0
# 2369  4740.0  9A9Y永豐板盛  47.4  1000.0     0
# 2370  4742.0  9A9Z永豐復興  47.0     0.0  2000
# 2371  4744.0  9A9Z永豐復興  48.0     0.0  2000

# %%
# change datatypes
df2['買進股數'] = df2['買進股數'].astype(np.int64)
df2.head()
# Out:
#      序號        券商     價格  買進股數   賣出股數
# 0   2.0  1020合　　庫  44.10  1000     0
# 1   4.0  1020合　　庫  44.60  1000     0
# 2   6.0  1020合　　庫  48.00     0  1000
# 3   8.0  1021合庫台中  44.50     0  2000
# 4  10.0  1021合庫台中  46.85  1000  1000

# %%
# join columns
df3 = pd.concat([df1, df2])
df3.head()
# Out:
#     序號        券商     價格  買進股數 賣出股數
# 0  1.0  1020合　　庫  43.90  1000    0
# 1  3.0  1020合　　庫  44.15  6000    0
# 2  5.0  1020合　　庫  47.40  1000    0
# 3  7.0  1021合庫台中  44.05  1000    0
# 4  9.0  1021合庫台中  45.80  1000    0

# %%
# check last few rows.
df3.tail()
# Out:
#           序號        券商    價格  買進股數   賣出股數
# 2367  4736.0  9A9X永豐竹科  47.0  2000     0
# 2368  4738.0  9A9Y永豐板盛  44.6  1000     0
# 2369  4740.0  9A9Y永豐板盛  47.4  1000     0
# 2370  4742.0  9A9Z永豐復興  47.0     0  2000
# 2371  4744.0  9A9Z永豐復興  48.0     0  2000

# %%
# Sort data
df4 = df3.sort_values(by=['序號'])
df4.head()
# Out:
#     序號        券商     價格  買進股數 賣出股數
# 0  1.0  1020合　　庫  43.90  1000    0
# 0  2.0  1020合　　庫  44.10  1000   0
# 1  3.0  1020合　　庫  44.15  6000    0
# 1  4.0  1020合　　庫  44.60  1000   0
# 2  5.0  1020合　　庫  47.40  1000    0

# %%
# reindex
#df4.reset_index
df4 = df4.reset_index()
df4 = df4.drop(df4.columns[[0,1]], axis=1) 
df4.head()
# Out:
#          券商     價格  買進股數 賣出股數
# 0  1020合　　庫  43.90  1000    0
# 1  1020合　　庫  44.10  1000   0
# 2  1020合　　庫  44.15  6000    0
# 3  1020合　　庫  44.60  1000   0
# 4  1020合　　庫  47.40  1000    0

# %%
# delete the price column
df8 = df4.drop(df4.columns[[1]], axis=1) 
df8.head()
# Out:
#          券商  買進股數 賣出股數
# 0  1020合　　庫  1000    0
# 1  1020合　　庫  1000   0
# 2  1020合　　庫  6000    0
# 3  1020合　　庫  1000   0
# 4  1020合　　庫  1000    0

# %%
# check datatypes
df8.dtypes
# Out:
# 券商      object
# 買進股數     int64
# 賣出股數    object
# dtype: object

# %%
# Check data type again
# Change datatypes
#df8["買進股數"] = df8["買進股數"].astype(str).astype(int)
df8["賣出股數"] = df8["賣出股數"].astype(str).astype(int)
df8.dtypes
# Out:
# 券商      object
# 買進股數     int64
# 賣出股數     int64
# dtype: object

# %%
# Check if datatypes are integers?
df8.head()
# Out:
#          券商  買進股數  賣出股數
# 0  1020合　　庫  1000     0
# 1  1020合　　庫  1000     0
# 2  1020合　　庫  6000     0
# 3  1020合　　庫  1000     0
# 4  1020合　　庫  1000     0

# %%
# Sum of 2 columns
df5 = df8.groupby(['券商']).agg({'買進股數':'sum','賣出股數':'sum'})
df5.head()
# Out:
#            買進股數  賣出股數
# 券商
# 1020合　　庫  10000  1000
# 1021合庫台中   5000  7000
# 1022合庫台南  33000  2000
# 1023合庫高雄   1000  5000
# 1024合庫嘉義   2000  2000

# %%
# Sub to get values and sort.
df5['差異']=df5['買進股數']-df5['賣出股數']

df5.head()
# Out:
#            買進股數  賣出股數     差異
# 券商
# 1020合　　庫  10000  1000   9000
# 1021合庫台中   5000  7000  -2000
# 1022合庫台南  33000  2000  31000
# 1023合庫高雄   1000  5000  -4000
# 1024合庫嘉義   2000  2000      0

# %%
# Sort by Value-差異
df6 = df5.sort_values(by=['差異'])

# return first 20 rows
# 顯示賣出量最大20間券商

# Change a column name
df6.columns = ['買進股數', '賣出股數', '今日賣超']

# Add a comma into an integer column
df6['今日賣超'] = df6.apply(lambda x: "{:,}".format(x['今日賣超']), axis=1)

df6.head(30)
# Out:
#               買進股數    賣出股數      今日賣超
# 券商
# 8440摩根大通     35000  189000  -154,000
# 8158台新松江     19000   83000   -64,000
# 601d类亞鑫豐     37000   90001   -53,001
# 1160日    盛   13000   61000   -48,000
# 888K國泰板橋     10000   58000   -48,000
# 1470台灣摩根         0   47000   -47,000
# 8380安    泰       0   47000   -47,000
# 9A9b永豐虎尾         0   46000   -46,000
# 9A9P永豐竹北      7000   45000   -38,000
# 981n元大旗山      1000   36000   -35,000
# 700M兆豐桃園      5000   38000   -33,000
# 1650瑞銀        7000   40000   -33,000
# 9801元大松江      1000   32000   -31,000
# 592D元富大昌      6058   36000   -29,942
# 779E國票南崁         0   29000   -29,000
# 913g群益南三     15000   41000   -26,000
# 888A國泰館前      9000   34000   -25,000
# 982C元大六合         0   24000   -24,000
# 9608富邦台東         0   23000   -23,000
# 5112富隆長安         0   23000   -23,000
# 116H日盛新竹      6000   27000   -21,000
# 585F統一彰化         0   21000   -21,000
# 700a兆豐忠孝      4000   23000   -19,000
# 918P群益天母      1000   20000   -19,000
# 9A9h永豐台南      4000   23000   -19,000
# 918x群益延平      7000   25000   -18,000
# 1440美林      262000  280000   -18,000
# 8563新光新竹     19000   37000   -18,000
# 9899元大淡水     11000   29000   -18,000
# 8565新光桃園      6100   24000   -17,900

# %%
# Reverse sort
df7 = df5.sort_values(by=['差異'],ascending=False)

# return first 20 rows
# 顯示買進量最大20間券商
df7.columns = ['買進股數', '賣出股數', '今日買超']

# Add a comma into an integer column
df7['今日買超'] = df7.apply(lambda x: "{:,}".format(x['今日買超']), axis=1)

df7.head(30)
# Out:
#               買進股數    賣出股數     今日買超
# 券商
# 5920元    富  247000    9000  238,000
# 980K元大竹科    164000    3000  161,000
# 585U統一南京    108000    6000  102,000
# 9268凱基台北    433000  346000   87,000
# 5850統    一   94000   11000   83,000
# 700P兆豐南京     82000       0   82,000
# 9287凱基內湖     60000       0   60,000
# 700i兆豐松德     53000       0   53,000
# 815A台新高雄     98000   49000   49,000
# 9358華南東勢     50000    2000   48,000
# 920D凱基市府     51000    3000   48,000
# 9692富邦嘉義    165000  119000   46,000
# 9600富邦       50000    5000   45,000
# 918s群益丹鳳     45000    1000   44,000
# 9659富邦高雄    116000   78000   38,000
# 965K富邦台中     53000   18000   35,000
# 5382第一台中     32000       0   32,000
# 9272凱基竹科     34000    3000   31,000
# 1022合庫台南     33000    2000   31,000
# 592U元富宜蘭     30000    1000   29,000
# 9A9C永豐員林     48000   20000   28,000
# 918L群益建成     32000    4000   28,000
# 9300華南永昌     54000   26000   28,000
# 8150台    新   80000   54000   26,000
# 7797國票中正     78000   54000   24,000
# 981F元大福營     29000    5000   24,000
# 9218凱基大直     51000   27000   24,000
# 9636富邦中壢     57000   35000   22,000
# 983N元大大安     29000    7000   22,000
# 5928元富新莊     41000   19000   22,000

# %%
# Sort values to get big tradings.
# 固定價錢買大單的券商排序
df4 = df4.sort_values(by=['買進股數'],ascending=False)

# Add a comma into an integer column
df4['買進股數'] = df4.apply(lambda x: "{:,}".format(x['買進股數']), axis=1)

df4.head(30)
# Out:
#               券商     價格     買進股數    賣出股數
# 3696    980K元大竹科  48.10  150,000       0
# 865     585U統一南京  48.10  100,000   2000
# 734   5850統    一  48.10   88,000       0
# 2995    9287凱基內湖  48.10   60,000      0
# 471       1440美林  48.00   59,000   1000
# 1442    700i兆豐松德  48.10   53,000       0
# 2759    9218凱基大直  48.10   51,000  10000
# 2926    9268凱基台北  47.20   50,000    1000
# 1818    815A台新高雄  48.10   49,000    2000
# 4630    9A9f永豐中盛  48.10   45,000    7000
# 2889    9268凱基台北  44.50   42,000  15000
# 892   5920元    富  44.25   41,000    2000
# 885   5920元    富  43.80   34,000      0
# 4629    9A9f永豐中盛  48.05   29,000  15000
# 2898    9268凱基台北  45.50   28,000       0
# 2922    9268凱基台北  47.00   28,000    1000
# 1745  8150台    新  48.10   26,000   2000
# 3197      9600富邦  46.95   25,000      0
# 421       1440美林  44.40   23,000   4000
# 2936    9268凱基台北  47.75   23,000    5000
# 895   5920元    富  44.40   23,000      0
# 3222    9616富邦岡山  44.30   23,000       0
# 1599    7797國票中正  46.00   22,000      0
# 899   5920元    富  44.60   22,000      0
# 3596    9692富邦嘉義  48.10   21,000    1000
# 4146    985C元大鳳中  48.00   20,000       0
# 3436    9659富邦高雄  48.10   20,000    1000
# 966     5928元富新莊  48.00   20,000       0
# 3573    9692富邦嘉義  46.50   20,000      0
# 769     5858統一嘉義  48.10   20,000      0

# %%
# check datatypes
df4.dtypes
# Out:
# 券商       object
# 價格      float64
# 買進股數     object
# 賣出股數     object
# dtype: object

# %%
# change datatypes
df4["賣出股數"] = df4["賣出股數"].astype(str).astype(int)

# %%
# Reverse sort to get big tradings.
# 固定價錢賣大單的券商排序
df4 = df4.sort_values(by=['賣出股數'],ascending=False)

# Add a comma into an integer column
df4['賣出股數'] = df4.apply(lambda x: "{:,}".format(x['賣出股數']), axis=1)

df4.head(30)
# Out:
#               券商     價格   買進股數    賣出股數
# 4628    9A9f永豐中盛  48.00      0  35,000
# 1770    8158台新松江  43.80      0  33,000
# 2918    9268凱基台北  46.80  1,000  31,000
# 3630    9801元大松江  44.60      0  30,000
# 3326    9636富邦中壢  47.00  8,000  27,000
# 1857    8440摩根大通  43.80      0  27,000
# 155   1160日    盛  47.20      0  26,000
# 2018    8561新光台中  46.95      0  25,000
# 1848  8380安    泰  44.25      0  25,000
# 2883    9268凱基台北  44.20      0  25,000
# 1627    779E國票南崁  48.10      0  24,000
# 1864    8440摩根大通  44.20      0  23,000
# 2077    8565新光桃園  48.10      0  23,000
# 3214    9608富邦台東  48.10      0  21,000
# 1863    8440摩根大通  44.15      0  21,000
# 1856    8440摩根大通  43.75      0  21,000
# 444       1440美林  46.50      0  21,000
# 2299    888A國泰館前  44.60      0  21,000
# 2940    9268凱基台北  48.00      0  20,000
# 3350    9651富邦民生  44.30      0  20,000
# 453       1440美林  47.00  5,000  20,000
# 2739    9215凱基高美  46.50      0  20,000
# 334     116N日盛永康  48.10      0  20,000
# 235     116C日盛八德  48.10      0  20,000
# 413       1440美林  44.00      0  20,000
# 4591    9A9C永豐員林  48.10      0  20,000
# 1849  8380安    泰  45.50      0  20,000
# 513       1650瑞銀  46.90      0  20,000
# 1734  8150台    新  47.20      0  20,000
# 1862    8440摩根大通  44.10      0  19,000

# %%
# Color
#df4.style.apply(highlight, axis=1)
#df4.iloc[0;] = 'background-color: red'
#df4.style.applymap(subset='賣出股數', color='#d65f5f')
#df4.head(5)
#df4.style.applymap(color_negative_red).apply(iloc[0;4])
#df4.head(5)
