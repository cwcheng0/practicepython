# %% [markdown]
# <a href="https://colab.research.google.com/github/cwcheng0/practicepython/blob/master/TaiwanStockCountOTC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To Read Taiwan Tourism Bureau data and make it into HTML
# Taiwan Stock Data1 https://bsr.twse.com.tw/bshtm/
# Filename: 2353_20200813.csv
# Taiwan Stock Data2 https://www.tpex.org.tw/web/stock/aftertrading/broker_trading/brokerBS.php
# Load basic libraries
import pandas as pd
import chardet
import codecs

# %%
# Mount personal Google Drive; all data files are in personal Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Create a file to see if it works
with open('/content/gdrive/My Drive/TourismData/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/gdrive/My\ Drive/TourismData/foo.txt
# Out:
# Hello Google Drive!

# %%
# Use PDrive function
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# List files in root directory
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: PythonCode, id: 1dFGhOQOJ9t5x5bJUph24v_N-mnmBKsMZ
# title: ContestData, id: 1hjni0UnbkVPr81RPHgSyH74jqF3XT6PS
# title: TourismData, id: 1rl2L8Vxmj4mqqFNCa23NUaypbVKazJRD
# title: Pixnet整理_Mike_20190804, id: 163PlI9NvQ5wVl62z6Crp4jihVWA4nnABRnPS8tU9neY
# title: Colab Notebooks, id: 13yubYLLF_3_MObjXoj-K2aGo-_UFoQZo
# title: bnbdata, id: 1yWUzpFHcZDftSVqbCaepJVd9oGsm2pww

# %%
# Check first 5 rows in a file
# from tabula import 
#df = pd.read_csv('/content/gdrive/My Drive/ContestData/FinanceData/2603_20200818.csv',encoding='ansi',skiprows=2)

#content = codecs.open("/content/gdrive/My Drive/ContestData/FinanceData/2603_20200818.csv", 'r', "ascii").write(content)
#codecs.open("/content/gdrive/My Drive/ContestData/FinanceData/2603_20200818a.csv", 'w', encoding="utf-8").write(content)

# Notice datatypes changed in some columns.
# Check first few rows.
df.head()
# Out:
#    序號        券商     價格   買進股數  賣出股數  序號.1      券商.1   價格.1  買進股數.1  賣出股數.1
# 0   1  1020合　　庫  23.15   2000     0     2  1020合　　庫  23.20    1000       0
# 1   3  1020合　　庫  23.25  10000  2000     4  1020合　　庫  23.30       0    2000
# 2   5  1020合　　庫  23.40  10000     0     6  1020合　　庫  23.60    3000       0
# 3   7  1020合　　庫  23.70  10000     0     8  1020合　　庫  23.75       0    1000
# 4   9  1020合　　庫  23.80   1000     0    10  1020合　　庫  23.85       0    2000

# %%
# Drop some columns.
df = df.drop(df.columns[[5]], axis=1) 
df.head()
# Out:
#    序號        券商     價格   買進股數  賣出股數      券商.1   價格.1  買進股數.1  賣出股數.1
# 0   1  1020合　　庫  23.15   2000     0  1020合　　庫  23.20    1000       0
# 1   3  1020合　　庫  23.25  10000  2000  1020合　　庫  23.30       0    2000
# 2   5  1020合　　庫  23.40  10000     0  1020合　　庫  23.60    3000       0
# 3   7  1020合　　庫  23.70  10000     0  1020合　　庫  23.75       0    1000
# 4   9  1020合　　庫  23.80   1000     0  1020合　　庫  23.85       0    2000

# %%
# Split fields into 2 files.
# Copy files
df1 = df
df2 = df
df1 = df1.drop(df.columns[[5,6,7,8]], axis=1) 
df1.head()
# Out:
#    序號        券商     價格   買進股數  賣出股數
# 0   1  1020合　　庫  23.15   2000     0
# 1   3  1020合　　庫  23.25  10000  2000
# 2   5  1020合　　庫  23.40  10000     0
# 3   7  1020合　　庫  23.70  10000     0
# 4   9  1020合　　庫  23.80   1000     0

# %%
# Do it again
df2 = df2.drop(df2.columns[[0,1,2,3,4]], axis=1) 
df2.head()
# Out:
#        券商.1   價格.1  買進股數.1  賣出股數.1
# 0  1020合　　庫  23.20    1000       0
# 1  1020合　　庫  23.30       0    2000
# 2  1020合　　庫  23.60    3000       0
# 3  1020合　　庫  23.75       0    1000
# 4  1020合　　庫  23.85       0    2000

# %%
# check datatypes
df2.dtypes
# Out:
# 券商.1       object
# 價格.1      float64
# 買進股數.1      int64
# 賣出股數.1      int64
# dtype: object

# %%
# Change column names
df2.columns = ['券商', '價格', '買進股數', '賣出股數']
df2.head()
# Out:
#          券商     價格  買進股數  賣出股數
# 0  1020合　　庫  23.20  1000     0
# 1  1020合　　庫  23.30     0  2000
# 2  1020合　　庫  23.60  3000     0
# 3  1020合　　庫  23.75     0  1000
# 4  1020合　　庫  23.85     0  2000

# %%
# cahnge datatypes
#df2['買進股數'] = df2['買進股數'].astype(int)
#df2.head()

# %%
# join columns
df3 = pd.concat([df1, df2])
df3.head()
# Out:
#     序號        券商     價格   買進股數  賣出股數
# 0  1.0  1020合　　庫  23.15   2000     0
# 1  3.0  1020合　　庫  23.25  10000  2000
# 2  5.0  1020合　　庫  23.40  10000     0
# 3  7.0  1020合　　庫  23.70  10000     0
# 4  9.0  1020合　　庫  23.80   1000     0

# %%
# check last few rows.
df3.tail()
# Out:
#       序號        券商     價格  買進股數  賣出股數
# 3268 NaN  9A9Y永豐板盛  23.90     0  8000
# 3269 NaN  9A9Z永豐復興  23.25     0  4000
# 3270 NaN  9A9Z永豐復興  23.50  2000     0
# 3271 NaN  9A9Z永豐復興  23.70     0  2000
# 3272 NaN  9A9Z永豐復興  23.85     0  8000

# %%
# Check if we need to delete the last row?
# delete last row
#df3.drop(df3.tail(1).index,inplace=True)
#df3.tail()

# %%
# Sort data
df4 = df3.sort_values(by=['序號'])
df4.head()
# Out:
#     序號        券商     價格   買進股數  賣出股數
# 0  1.0  1020合　　庫  23.15   2000     0
# 1  3.0  1020合　　庫  23.25  10000  2000
# 2  5.0  1020合　　庫  23.40  10000     0
# 3  7.0  1020合　　庫  23.70  10000     0
# 4  9.0  1020合　　庫  23.80   1000     0

# %%
# reindex
#df4.reset_index
df4 = df4.reset_index()
df4 = df4.drop(df4.columns[[0,1]], axis=1) 
df4.head()
# Out:
#          券商     價格   買進股數  賣出股數
# 0  1020合　　庫  23.15   2000     0
# 1  1020合　　庫  23.25  10000  2000
# 2  1020合　　庫  23.40  10000     0
# 3  1020合　　庫  23.70  10000     0
# 4  1020合　　庫  23.80   1000     0

# %%
# delete the price column
df8 = df4.drop(df4.columns[[1]], axis=1) 
df8.head()
# Out:
#          券商   買進股數  賣出股數
# 0  1020合　　庫   2000     0
# 1  1020合　　庫  10000  2000
# 2  1020合　　庫  10000     0
# 3  1020合　　庫  10000     0
# 4  1020合　　庫   1000     0

# %%
# check datatypes
df8.dtypes
# Out:
# 券商      object
# 買進股數     int64
# 賣出股數     int64
# dtype: object

# %%
# Check data type again
# Change datatypes
#df8["買進股數"] = df8["買進股數"].astype(str).astype(int)
#df8["賣出股數"] = df8["賣出股數"].astype(str).astype(int)
#df8.dtypes

# %%
# Check if datatypes are integers?
df8.head()
# Out:
#          券商   買進股數  賣出股數
# 0  1020合　　庫   2000     0
# 1  1020合　　庫  10000  2000
# 2  1020合　　庫  10000     0
# 3  1020合　　庫  10000     0
# 4  1020合　　庫   1000     0

# %%
# Sum of 2 columns
df5 = df8.groupby(['券商']).agg({'買進股數':'sum','賣出股數':'sum'})
df5.head()
# Out:
#            買進股數    賣出股數
# 券商
# 1020合　　庫  37000    7000
# 1021合庫台中  42010  103503
# 1022合庫台南  20000    3000
# 1023合庫高雄  12000    7000
# 1024合庫嘉義   1000    3000

# %%
# Sub to get values and sort.
df5['差異']=df5['買進股數']-df5['賣出股數']
df5.head()
# Out:
#            買進股數    賣出股數     差異
# 券商
# 1020合　　庫  37000    7000  30000
# 1021合庫台中  42010  103503 -61493
# 1022合庫台南  20000    3000  17000
# 1023合庫高雄  12000    7000   5000
# 1024合庫嘉義   1000    3000  -2000

# %%
# Sort by Value-差異
df6 = df5.sort_values(by=['差異'])

# return first 20 rows
# 顯示賣出量最大20間券商
df6.head(20)
# Out:
#               買進股數     賣出股數       差異
# 券商
# 8450康    和   14000  1030000 -1016000
# 5850統    一   30000   841000  -811000
# 1360港麥格理         0   803000  -803000
# 9697富邦虎尾    218000   931000  -713000
# 700F兆豐虎尾     94000   535000  -441000
# 9200凱基        9000   440000  -431000
# 7790國票綜合    104000   531000  -427000
# 9A00永豐金      16434   427167  -410733
# 9218凱基大直     20000   415000  -395000
# 8880國泰綜合    177000   544967  -367967
# 9238凱基士林     14000   324000  -310000
# 1030土　　銀     18000   309000  -291000
# 7035致和東門     15000   300000  -285000
# 9800元大      104000   375000  -271000
# 7000兆豐       18000   260000  -242000
# 989N元大內湖    109000   344341  -235341
# 9297凱基文心      2000   228000  -226000
# 638D光和高雄     27000   237000  -210000
# 815B台新台中    157501   350200  -192699
# 983G元大上新     12000   203000  -191000

# %%
# Reverse sort
df7 = df5.sort_values(by=['差異'],ascending=False)

# return first 20 rows
# 顯示買進量最大20間券商
df7.head(20)
# Out:
#                買進股數     賣出股數       差異
# 券商
# 1470台灣摩根    4549000   577000  3972000
# 1520瑞士信貸    4456000  1365000  3091000
# 1440美林      2136000  1476000   660000
# 1650瑞銀       593000    55000   538000
# 8840玉    山   567000    65016   501984
# 9600富邦       445000        0   445000
# 9291凱基大安     422000    18000   404000
# 1560港商野村     490000   103000   387000
# 1480美商高盛     388000     5000   383000
# 1590花旗環球     245000        0   245000
# 611A中銀豐原     417000   215000   202000
# 616A中信中壢     230000    31000   199000
# 9898元大新莊     246000    57000   189000
# 116B日盛中壢     190000    11000   179000
# 700K兆豐新營     188000    41000   147000
# 9268凱基台北     601000   454000   147000
# 779H國票嘉義     136000     4000   132000
# 1570港商法興     125000        0   125000
# 913D群益潭子     138000    15000   123000
# 922H凱基復興     114000     5000   109000

# %%
# Sort values to get big tradings.
df4 = df4.sort_values(by=['買進股數'],ascending=True)
df4.tail(30)
# Out:
#               券商     價